# %%
#importing libraries
import pandas as pd
import seaborn as sns

#visualizaton libraries
from matplotlib import  pyplot as plt
import seaborn as sns

#supress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#uploading dataset
df= pd.read_csv('Goal4.csv')

# %%
df.dtypes
# Out:
# Goal                   int64
# Target                object
# Indicator             object
# SeriesCode            object
# SeriesDescription     object
# GeoAreaCode            int64
# GeoAreaName           object
# TimePeriod             int64
# Value                float64
# Time_Detail           object
# TimeCoverage         float64
# UpperBound           float64
# LowerBound           float64
# BasePeriod           float64
# Source                object
# GeoInfoUrl           float64
# FootNote              object
# Age                   object
# Education level       object
# Location              object
# Nature                object
# Quantile              object
# Reporting Type        object
# Sex                   object
# Type of skill         object
# Units                 object
# Unnamed: 26          float64
# Unnamed: 27          float64
# Unnamed: 28          float64
# Unnamed: 29          float64
# Unnamed: 30          float64
# Unnamed: 31          float64
# ...

# %%
df.head()
# Out:
#    Goal Target Indicator   SeriesCode  \
# 0     4    4.1     4.1.1  SE_TOT_PRFL
# 1     4    4.1     4.1.1  SE_TOT_PRFL
# 2     4    4.1     4.1.1  SE_TOT_PRFL
# 3     4    4.1     4.1.1  SE_TOT_PRFL
# 4     4    4.1     4.1.1  SE_TOT_PRFL
#
#                                    SeriesDescription  GeoAreaCode  \
# 0  Proportion of children and young people achiev...            4
# 1  Proportion of children and young people achiev...            4
# 2  Proportion of children and young people achiev...            4
# 3  Proportion of children and young people achiev...            4
# 4  Proportion of children and young people achiev...            4
#
#    GeoAreaName  TimePeriod  Value Time_Detail  ...  Unnamed: 42  Unnamed: 43  \
# 0  Afghanistan        2013   11.0        2013  ...          NaN          NaN
# 1  Afghanistan        2013   13.0        2013  ...          NaN          NaN
# 2  Afghanistan        2016   21.5        2016  ...          NaN          NaN
# ...

# %%
df.shape
# Out:
# (191762, 52)

# %%
#checking missing values using heatmap
plt.figure(figsize=(15,7))
sns.heatmap(df.isnull(),cbar=True)
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# Goal                      0
# Target                    0
# Indicator                 0
# SeriesCode                0
# SeriesDescription         0
# GeoAreaCode               0
# GeoAreaName               0
# TimePeriod                0
# Value                 12192
# Time_Detail               0
# TimeCoverage         191762
# UpperBound           191762
# LowerBound           191762
# BasePeriod           189486
# Source                    0
# GeoInfoUrl           191762
# FootNote             176950
# Age                  191281
# Education level       17879
# Location              78911
# Nature                    0
# Quantile              55387
# Reporting Type            0
# Sex                   48829
# Type of skill        175898
# Units                     0
# Unnamed: 26          191762
# Unnamed: 27          191762
# Unnamed: 28          191762
# Unnamed: 29          191762
# Unnamed: 30          191762
# Unnamed: 31          191762
# Unnamed: 32          191762
# ...

# %%
#identifying blank columns
blank_columns = list(df.columns[df.isnull().sum()==df.shape[0]])
blank_columns
# Out:
# ['TimeCoverage',
#  'UpperBound',
#  'LowerBound',
#  'GeoInfoUrl',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
#  'Unnamed: 29',
#  'Unnamed: 30',
#  'Unnamed: 31',
#  'Unnamed: 32',
#  'Unnamed: 33',
#  'Unnamed: 34',
#  'Unnamed: 35',
#  'Unnamed: 36',
#  'Unnamed: 37',
#  'Unnamed: 38',
#  'Unnamed: 39',
#  'Unnamed: 40',
#  'Unnamed: 41',
#  'Unnamed: 42',
#  'Unnamed: 43',
#  'Unnamed: 44',
#  'Unnamed: 45',
#  'Unnamed: 46',
#  'Unnamed: 47',
#  'Unnamed: 48',
#  'Unnamed: 49',
#  'Unnamed: 50',
#  'Unnamed: 51']

# %%
df = df.drop(blank_columns,axis=1)

# %%
df.head()
# Out:
#    Goal Target Indicator   SeriesCode  \
# 0     4    4.1     4.1.1  SE_TOT_PRFL
# 1     4    4.1     4.1.1  SE_TOT_PRFL
# 2     4    4.1     4.1.1  SE_TOT_PRFL
# 3     4    4.1     4.1.1  SE_TOT_PRFL
# 4     4    4.1     4.1.1  SE_TOT_PRFL
#
#                                    SeriesDescription  GeoAreaCode  \
# 0  Proportion of children and young people achiev...            4
# 1  Proportion of children and young people achiev...            4
# 2  Proportion of children and young people achiev...            4
# 3  Proportion of children and young people achiev...            4
# 4  Proportion of children and young people achiev...            4
#
#    GeoAreaName  TimePeriod  Value Time_Detail  ...  FootNote  Age  \
# 0  Afghanistan        2013   11.0        2013  ...       NaN  NaN
# 1  Afghanistan        2013   13.0        2013  ...       NaN  NaN
# 2  Afghanistan        2016   21.5        2016  ...       NaN  NaN
# ...

# %%
#checking number of Countries
df['GeoAreaName'].value_counts()
# Out:
# Dominican Republic                  6129
# Costa Rica                          6108
# Peru                                6024
# Bolivia (Plurinational State of)    5570
# Panama                              5493
#                                     ...
# Polynesia                             13
# Middle Africa                         13
# Eastern Africa                        13
# Curaçao                               12
# Wallis and Futuna Islands              7
# Name: GeoAreaName, Length: 254, dtype: int64

# %%
#checking number of country codes
df['GeoAreaCode'].value_counts()
# Out:
# 214    6129
# 188    6108
# 604    6024
# 68     5570
# 591    5493
#        ...
# 11       13
# 17       13
# 127      13
# 531      12
# 876       7
# Name: GeoAreaCode, Length: 254, dtype: int64

# %%
#checking unique values of countries
df['GeoAreaName'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Azerbaijan', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Armenia',
#        'Belgium', 'Bhutan', 'Bosnia and Herzegovina', 'Botswana',
#        'Brazil', 'Belize', 'Brunei Darussalam', 'Bulgaria', 'Burundi',
#        'Belarus', 'Cambodia', 'Cameroon', 'Canada', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo',
#        'Democratic Republic of the Congo', 'Costa Rica', 'Croatia',
#        'Cuba', 'Cyprus', 'Czechia', 'Benin', 'Denmark',
#        'Dominican Republic', 'Ecuador', 'El Salvador', 'Estonia',
#        'Finland', 'France', 'Gabon', 'Georgia', 'Gambia',
#        'State of Palestine', 'Germany', 'Ghana', 'Greece', 'Guatemala',
#        'Honduras', 'China, Hong Kong Special Administrative Region',
#        'Hungary', 'Iceland', 'India', 'Indonesia',
#        'Iran (Islamic Republic of)', 'Ireland', 'Israel', 'Italy',
#        "Côte d'Ivoire", 'Japan', 'Kazakhstan', 'Jordan', 'Kenya',
# ...

# %%
#creating a dictionary based on country code and country names
country_dic = {df['GeoAreaCode'][i]: df['GeoAreaName'][i] for i in range(len(df['GeoAreaCode']))}

# %%
#Country of focus as mentioned in the instructions
countries = ['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Azerbaijan', 'Bangladesh', 'Belarus', 'Belize', 'Benin', 'Bhutan','Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon', 'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia', 'Comoros', 'Congo','Congo, Democratic Republic', 'Costa Rica', 'Croatia', "Côte d'Ivoire", 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Fiji', 'Gabon', 'Gambia', 'Georgia', 'Ghana', 'Grenada', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras', 'India', 'Indonesia', 'Iran (Islamic Republic of)', 'Iraq', 'Jamaica', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kyrgyzstan', "Lao People's Democratic Republic", 'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico', 'Micronesia (Federated States of)','Moldova', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Nicaragua', 'Niger', 'Nigeria', 'North Macedonia', 'Pakistan', 'Palau', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Romania', 'Russian Federation', 'Rwanda', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'Samoa', 'Sao Tome and Principe', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Solomon Islands', 'Somalia', 'South Africa', 'South Sudan', 'Sri Lanka', 'Sudan', 'Suriname', 'Syrian Arab Republic', 'Tajikistan', 'Thailand', 'Timor-Leste', 'Togo', 'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Tuvalu', 'Uganda', 'Ukraine', 'United Republic of Tanzania', 'Uruguay', 'Uzbekistan', 'Vanuatu','Venezuela', 'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe']
country_focus_list = [4,8,12,24,28,31,32,50,51,64,68,70,72,76,84,90,100,104,108,112,116,120,132,140,144,148,152,156,170,174,178,178,178,180,188,191,204,212,214,218,222,226,231,232,242,262,266,268,270,288,296,308,320,324,328,332,340,356,360,364,368,384,388,398,400,404,412,417,418,422,426,430,434,450,454,458,462,466,478,480,484,496,498,499,504,508,516,520,524,548,558,562,566,583,584,585,586,591,598,600,604,608,616,624,626,642,643,646,659,662,670,678,686,688,690,694,704,706,710,716,728,729,740,748,760,762,764,768,776,780,788,792,795,798,800,804,807,818,834,854,858,860,862,882,887,894]

# %%
df.isnull().sum()
# Out:
# Goal                      0
# Target                    0
# Indicator                 0
# SeriesCode                0
# SeriesDescription         0
# GeoAreaCode               0
# GeoAreaName               0
# TimePeriod                0
# Value                 12192
# Time_Detail               0
# BasePeriod           189486
# Source                    0
# FootNote             176950
# Age                  191281
# Education level       17879
# Location              78911
# Nature                    0
# Quantile              55387
# Reporting Type            0
# Sex                   48829
# Type of skill        175898
# Units                     0
# dtype: int64

# %%
df = df[df["GeoAreaCode"].isin(country_focus_list)]

# %%
#dropping Time_detail as it is similar to TimePeriod
df = df.drop('Time_Detail',axis=1)

# %%
#dropping Source and FootNote since they are irrelevant to our analysis
df = df.drop(['Source','FootNote'],axis=1)

# %%
df
# Out:
#         Goal Target Indicator   SeriesCode  \
# 0          4    4.1     4.1.1  SE_TOT_PRFL
# 1          4    4.1     4.1.1  SE_TOT_PRFL
# 2          4    4.1     4.1.1  SE_TOT_PRFL
# 3          4    4.1     4.1.1  SE_TOT_PRFL
# 4          4    4.1     4.1.1  SE_TOT_PRFL
# ...      ...    ...       ...          ...
# 191757     4    4.c     4.c.1  SE_TRA_GRDL
# 191758     4    4.c     4.c.1  SE_TRA_GRDL
# 191759     4    4.c     4.c.1  SE_TRA_GRDL
# 191760     4    4.c     4.c.1  SE_TRA_GRDL
# 191761     4    4.c     4.c.1  SE_TRA_GRDL
#
#                                         SeriesDescription  GeoAreaCode  \
# 0       Proportion of children and young people achiev...            4
# 1       Proportion of children and young people achiev...            4
# 2       Proportion of children and young people achiev...            4
# 3       Proportion of children and young people achiev...            4
# 4       Proportion of children and young people achiev...            4
# ...

# %%
#checking missing values by target
target = list(df['Target'].value_counts().index)
target
# Out:
# [4.1, 4.5, '4.c', 4.2, '4.a', 4.4, '4.b', 4.3, '4.5', '4.6']

# %%
#looking if missing values has specific correlation with the target

for item in target:
    print("Target ",item,end="\n\n")
    print("Total records = ",df[df["Target"]==item].shape[0],end="\n\n")
    print("Missing Values Count: \n",df[df["Target"]==item].isnull().sum(),end="\n\n\n\n")
# Out:
# Target  4.1
#
# Total records =  75370
#
# Missing Values Count:
#  Goal                     0
# Target                   0
# Indicator                0
# SeriesCode               0
# SeriesDescription        0
# GeoAreaCode              0
# GeoAreaName              0
# TimePeriod               0
# Value                 4207
# BasePeriod           75370
# Age                  75370
# Education level          0
# Location              1944
# Nature                   0
# Quantile              1944
# Reporting Type           0
# Sex                      0
# Type of skill        73426
# Units                    0
# dtype: int64
#
#
#
# Target  4.5
#
# Total records =  64575
#
# Missing Values Count:
#  Goal                     0
# Target                   0
# Indicator                0
# SeriesCode               0
# SeriesDescription        0
# GeoAreaCode              0
# GeoAreaName              0
# TimePeriod               0
# Value                 7265
# BasePeriod           64575
# ...

# %%
df[df["Target"]=="4.c"].shape
# Out:
# (8845, 19)

# %%
#checking missing values by indicator
indicator = list(df['Indicator'].value_counts().index)
indicator
# Out:
# ['4.1.2',
#  '4.5.1',
#  '4.c.1',
#  '4.a.1',
#  '4.2.2',
#  '4.4.1',
#  '4.1.1',
#  '4.b.1',
#  '4.3.1',
#  '4.2.1',
#  '4.6.1']

# %%
#looking if missing values has specific correlation with the target

for item1 in indicator:
    print("Indicator ",item1,end="\n\n")
    print("Total records = ",df[df["Indicator"]==item1].shape[0],end="\n\n")
    print("Missing Values Count: \n",df[df["Indicator"]==item1].isnull().sum(),end="\n\n\n\n")
# Out:
# Indicator  4.1.2
#
# Total records =  73426
#
# Missing Values Count:
#  Goal                     0
# Target                   0
# Indicator                0
# SeriesCode               0
# SeriesDescription        0
# GeoAreaCode              0
# GeoAreaName              0
# TimePeriod               0
# Value                 4207
# BasePeriod           73426
# Age                  73426
# Education level          0
# Location                 0
# Nature                   0
# Quantile                 0
# Reporting Type           0
# Sex                      0
# Type of skill        73426
# Units                    0
# dtype: int64
#
#
#
# Indicator  4.5.1
#
# Total records =  65144
#
# Missing Values Count:
#  Goal                     0
# Target                   0
# Indicator                0
# SeriesCode               0
# SeriesDescription        0
# GeoAreaCode              0
# GeoAreaName              0
# TimePeriod               0
# Value                 7265
# ...

# %%
#since indicator explains the correlation well, we will make analysis based on indicator.
#This would also means that we can drop Goal, Target,Series Code, Series Description column as they are all represented by the indicator.

# %%
## Data Imputation
df.head()
# Out:
#    Goal Target Indicator   SeriesCode  \
# 0     4    4.1     4.1.1  SE_TOT_PRFL
# 1     4    4.1     4.1.1  SE_TOT_PRFL
# 2     4    4.1     4.1.1  SE_TOT_PRFL
# 3     4    4.1     4.1.1  SE_TOT_PRFL
# 4     4    4.1     4.1.1  SE_TOT_PRFL
#
#                                    SeriesDescription  GeoAreaCode  \
# 0  Proportion of children and young people achiev...            4
# 1  Proportion of children and young people achiev...            4
# 2  Proportion of children and young people achiev...            4
# 3  Proportion of children and young people achiev...            4
# 4  Proportion of children and young people achiev...            4
#
#    GeoAreaName  TimePeriod  Value  BasePeriod  Age Education level Location  \
# 0  Afghanistan        2013   11.0         NaN  NaN          PRIMAR      NaN
# 1  Afghanistan        2013   13.0         NaN  NaN          PRIMAR      NaN
# 2  Afghanistan        2016   21.5         NaN  NaN          GRAD23      NaN
# ...

# %%
df.SeriesDescription.values
# Out:
# array(['Proportion of children and young people achieving a minimum proficiency level in reading and mathematics (%)',
#        'Proportion of children and young people achieving a minimum proficiency level in reading and mathematics (%)',
#        'Proportion of children and young people achieving a minimum proficiency level in reading and mathematics (%)',
#        ...,
#        'Proportion of teachers who have received at least the minimum organized teacher training (e.g. pedagogical training) pre-service or in-service required for teaching at the relevant level in a given country, by sex and education level (%)',
#        'Proportion of teachers who have received at least the minimum organized teacher training (e.g. pedagogical training) pre-service or in-service required for teaching at the relevant level in a given country, by sex and education level (%)',
# ...

# %%
## Summary statistcs of values at the SeriesDescription and GeoAreaCode
df.groupby(["SeriesDescription", "GeoAreaCode"])['Value'].describe()
# Out:
#                                                                 count  \
# SeriesDescription                                  GeoAreaCode
# Adjusted gender parity index for completion rat... 4            101.0
#                                                    8             99.0
#                                                    12            54.0
#                                                    24            45.0
#                                                    31            50.0
# ...                                                               ...
# Total official flows for scholarships, by recip... 860           13.0
#                                                    862           13.0
#                                                    882           13.0
#                                                    887           13.0
#                                                    894           13.0
#
# ...

# %%
df["Value"] = df.groupby(["SeriesDescription", "GeoAreaCode"]).transform(lambda x: x.fillna(x.mean()))

# %%
## Summary Statistics of BasePeriod
df.groupby(["SeriesDescription", "GeoAreaCode"])['BasePeriod'].describe()
# Out:
#                                                                 count    mean  \
# SeriesDescription                                  GeoAreaCode
# Adjusted gender parity index for completion rat... 4              0.0     NaN
#                                                    8              0.0     NaN
#                                                    12             0.0     NaN
#                                                    24             0.0     NaN
#                                                    31             0.0     NaN
# ...                                                               ...     ...
# Total official flows for scholarships, by recip... 860           13.0  2018.0
#                                                    862           13.0  2018.0
#                                                    882           13.0  2018.0
#                                                    887           13.0  2018.0
# ...

# %%
df["BasePeriod"] = df.groupby(["SeriesDescription", "GeoAreaCode"]).transform(lambda x: x.fillna(x.interpolate()))

# %%
print(df["Value"].isnull().any())
print(df["BasePeriod"].isnull().any())
# Out:
# False
# False

# %%
cols = ["Age", "BasePeriod"]
df[cols] = df[cols].apply(pd.to_numeric, errors = "coerce", axis = 1)

# %%
## Summary Statistics for Age
df.groupby(["SeriesDescription", "GeoAreaCode"])['Age'].describe()
# Out:
#                                                                 count  mean  \
# SeriesDescription                                  GeoAreaCode
# Adjusted gender parity index for completion rat... 4              0.0   NaN
#                                                    8              0.0   NaN
#                                                    12             0.0   NaN
#                                                    24             0.0   NaN
#                                                    31             0.0   NaN
# ...                                                               ...   ...
# Total official flows for scholarships, by recip... 860            0.0   NaN
#                                                    862            0.0   NaN
#                                                    882            0.0   NaN
#                                                    887            0.0   NaN
# ...

# %%
df["Age"] = df.groupby(["SeriesDescription", "GeoAreaCode"]).transform(lambda x: x.fillna(x.mean()))

# %%
df["Education level"] = df.groupby(["SeriesDescription", "GeoAreaCode"]).transform(lambda x: x.fillna(x.mode()))

# %%
df.isnull().sum()
# Out:
# Goal                      0
# Target                    0
# Indicator                 0
# SeriesCode                0
# SeriesDescription         0
# GeoAreaCode               0
# GeoAreaName               0
# TimePeriod                0
# Value                     0
# BasePeriod                0
# Age                       0
# Education level           0
# Location              51838
# Nature                    0
# Quantile              28734
# Reporting Type            0
# Sex                   34917
# Type of skill        153700
# Units                     0
# dtype: int64

# %%
df["Location"] = df.groupby(["SeriesDescription", "GeoAreaCode"]).transform(lambda x: x.fillna(x.mode()))

# %%
df["Quantile"] = df.groupby(["SeriesDescription", "GeoAreaCode"]).transform(lambda x: x.fillna(x.mode()))

# %%
df["Sex"] = df.groupby(["SeriesDescription", "GeoAreaCode"]).transform(lambda x: x.fillna(x.mode()))

# %%
df["Type of skill"] = df.groupby(["SeriesDescription", "GeoAreaCode"]).transform(lambda x: x.fillna(x.mode()))

# %%
## MODEL BUILDING
### Multilevel Vector Autoregressive model

# %%
df.isnull().any()
# Out:
# Goal                 False
# Target               False
# Indicator            False
# SeriesCode           False
# SeriesDescription    False
# GeoAreaCode          False
# GeoAreaName          False
# TimePeriod           False
# Value                False
# BasePeriod           False
# Age                  False
# Education level      False
# Location             False
# Nature               False
# Quantile             False
# Reporting Type       False
# Sex                  False
# Type of skill        False
# Units                False
# dtype: bool

# %%
#trainset = df.iloc[""]
testset = df[df["TimePeriod"] == 2019]
trainset = df[df["TimePeriod"] != 2019]

# %%
from statsmodels.tsa.vector_ar.var_model import VAR

# %%
# Out:
#    Goal Target Indicator   SeriesCode  \
# 0     4    4.1     4.1.1  SE_TOT_PRFL
# 1     4    4.1     4.1.1  SE_TOT_PRFL
# 2     4    4.1     4.1.1  SE_TOT_PRFL
# 3     4    4.1     4.1.1  SE_TOT_PRFL
# 4     4    4.1     4.1.1  SE_TOT_PRFL
#
#                                    SeriesDescription  GeoAreaCode  \
# 0  Proportion of children and young people achiev...            4
# 1  Proportion of children and young people achiev...            4
# 2  Proportion of children and young people achiev...            4
# 3  Proportion of children and young people achiev...            4
# 4  Proportion of children and young people achiev...            4
#
#    GeoAreaName  TimePeriod  Value  BasePeriod  Age Education level Location  \
# 0  Afghanistan        2013    4.0         4.0  4.0               4        4
# 1  Afghanistan        2013    4.0         4.0  4.0               4        4
# 2  Afghanistan        2016    4.0         4.0  4.0               4        4
# ...
